# %% [markdown]
# #
#
# <div align=center>
# <img src="https://uol.unifor.br/acesso/app/autenticacao/assets/img/logos/icon-unifor.svg" width=45 height=45>
# <img src="https://vortex.unifor.br/assets/logos/v1.png" width=45 height=45>
# <img src="https://ouch-cdn2.icons8.com/YGkdXgv0NLHfLDlV7bbprOdJuob-J4_zBkql2tweSAk/rs:fit:296:456/extend:false/wm:1:re:0:0:0.8/wmid:ouch/czM6Ly9pY29uczgu/b3VjaC1wcm9kLmFz/c2V0cy9zdmcvNjY5/Lzc2NWQ4ZWU1LWE0/NzItNDMzZi04MGI0/LWZiYWRlZTc1NmVh/Yy5zdmc.png
# " width=45 height=45>
#
# <font size=5 color='white'>
# <br><br>
# <font size=5 color='white'><strong>Projeto:</strong> Pellis
#
# <strong>Etapa:</strong> Treinamento e teste
#
# <strong>Autoria:</strong> Heitor Teixeira
#
# </div>

# %% [markdown]
# ##
# <font size=5 color='white'> 0 - Bibliotecas e configuração de GPU

# %%
import tensorflow as tf
import time
import os
import pandas as pd
from sklearn.model_selection import train_test_split
import GPUtil
from tensorflow.keras.optimizers import Adam, SGD, RMSprop # type: ignore
from tensorflow.keras.losses import CategoricalCrossentropy
from auxiliar.dataset import criar_dataset
from auxiliar.avaliar import avaliar_modelo, matriz_confusao, proximo_id
from auxiliar.callbacks import callbacks
from auxiliar.arquiteturas import custom_model

tf_gpu = tf.config.experimental.list_physical_devices('GPU')
if tf_gpu:
    try:
        nome_gpu = GPUtil.getGPUs()
        print("GPU configurada: ", nome_gpu[0].name)
        tf.config.experimental.set_memory_growth(tf_gpu[0], True)
    except RuntimeError as e:
        print(e)
# Out:
# GPU configurada:  NVIDIA GeForce RTX 4080
# Physical devices cannot be modified after being initialized

# %% [markdown]
# ##
# <font size=5 color='white'> 1 - Hiperparametros

# %%
'''
ao lado o batchsize que comporta na minha placa de vídeo, adequa com o que couber.
'''

redes = [
        ['EfficientNetV2B3', 50],  # 0
        ['EfficientNetV2S', 16],   # 1
        ['EfficientNetV2M', 10],   # 2
        ['EfficientNetV2L', 5],    # 3
        ['InceptionV3', 80],       # 4
        ['InceptionResNetV2', 50], # 5
        ['ResNet50V2', 150],       # 6
        ['ResNet152V2', 50],       # 7 
        ['ResNeXt50', 30],         # 8
        ['ResNeXt101', 16]         # 9 
]

# %%
seed = 51 # boa ideia 
id_rodada = proximo_id('./rodadas.csv')
n_rede = 3
rede = redes[n_rede][0]
batch_size = redes[n_rede][1]

epocas = 100
loss = CategoricalCrossentropy()
nome_loss = 'CategoricalCrossentropy' # uma string pra salvar no csv
lr = 0.00001

otimizador = Adam(learning_rate = lr) # Adam, SGD, RMSprop
nome_otimizador = 'adam' # uma string pra salvar no csv 

attention = '-' # 'se' ou 'cbam'. as 2 camadas de attention que adicionei caso queria treinar com
camada_pooling = 'global_avg' # 'global_max', 'global_avg'
flatten = False 
imagenet = 'imagenet' # imagenet, imagenet-21k, imagenet-21k-ft1k, os modelos efficient net podem ser treinados na 21k

'''
proejetei pra aceitar ate 5 camadas densas, é so ajustar que da pra aumentar. so acho que nao precisa
'''

denses = [1024, 256] 
dropouts = [0.5, 0.1] 
data_aug = True

# %% [markdown]
# ##
# <font size=5 color='white'> 2 - Importando dados e criando datasets

# %%
dir_dados_treino = '../pellis_treino.csv'
dir_imagens_treino = '../imagens/treino_imagens'

dir_dados_teste = '../pellis_teste.csv'
dir_imagens_teste = '../imagens/teste_imagens'

dir_modelos_salvos = f'./redes/{rede}/modelos_salvos/{rede}-{id_rodada}_epoca_{{epoch:02d}}.hdf5'
dir_csv_log_treino = f'./redes/{rede}/log_treino/{rede}-{id_rodada}_treinamento_log.csv'

val_size = 0.15

dados_treino = pd.read_csv(dir_dados_treino)
dados_teste = pd.read_csv(dir_dados_teste)

dados_treino, dados_validacao = train_test_split(
    dados_treino,
    random_state=seed,
    test_size = val_size,
)

print(len(dados_treino))
print(len(dados_validacao))
print(len(dados_teste))
# Out:
# 1698
# 300
# 503

# %%
dataset_treino = criar_dataset(
    dataframe = dados_treino,
    diretorio = dir_imagens_treino,
    batch_size = batch_size,
    rede = rede,
    shuffle = True,
    data_aug = data_aug
)

dataset_validacao = criar_dataset(
    dataframe = dados_validacao,
    diretorio = dir_imagens_treino,
    batch_size = batch_size,
    rede = rede,
)

dataset_teste = criar_dataset(
    dataframe = dados_teste,
    diretorio = dir_imagens_teste,
    batch_size = batch_size,
    rede = rede,

)

# %% [markdown]
# ##
# <font size=5 color='white'> 3 - Modelando a rede

# %%
# ja foi comentado nos arquivos auxiliares
model = custom_model(
    rede= rede,
    loss = loss,
    weights = imagenet,
    otimizador = otimizador, 
    attention = attention, 
    denses = denses,
    dropouts = dropouts,
    pooling = camada_pooling,
    flatten=flatten
)

num_layers = len(model.layers)
print(f'camadas no modelo: {num_layers}')

model.summary()
# Out:
# camadas no modelo: 1033
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  stem_conv (Conv2D)             (None, None, None,   864         ['input_1[0][0]']
#                                 32)
#
#  stem_bn (BatchNormalization)   (None, None, None,   128         ['stem_conv[0][0]']
#                                 32)
#
#  stem_activation (Activation)   (None, None, None,   0           ['stem_bn[0][0]']
#                                 32)
#
#  block1-01_project_conv (Conv2D  (None, None, None,   9216       ['stem_activation[0][0]']
#  )                              32)
#
#  block1-01_project_bn (BatchNor  (None, None, None,   128        ['block1-01_project_conv[0][0]']
#  malization)                    32)
#
#  block1-01_project_activation (  (None, None, None,   0          ['block1-01_project_bn[0][0]']
#  Activation)                    32)
#
#  block1-01_add (Add)            (None, None, None,   0           ['block1-01_project_activation[0]
#                                 32)                              [0]',
#                                                                   'stem_activation[0][0]']
#
#  block1-02_project_conv (Conv2D  (None, None, None,   9216       ['block1-01_add[0][0]']
#  )                              32)
#
#  block1-02_project_bn (BatchNor  (None, None, None,   128        ['block1-02_project_conv[0][0]']
#  malization)                    32)
#
#  block1-02_project_activation (  (None, None, None,   0          ['block1-02_project_bn[0][0]']
#  Activation)                    32)
#
#  block1-02_drop (Dropout)       (None, None, None,   0           ['block1-02_project_activation[0]
#                                 32)                              [0]']
#
#  block1-02_add (Add)            (None, None, None,   0           ['block1-02_drop[0][0]',
#                                 32)                               'block1-01_add[0][0]']
#
#  block1-03_project_conv (Conv2D  (None, None, None,   9216       ['block1-02_add[0][0]']
#  )                              32)
#
#  block1-03_project_bn (BatchNor  (None, None, None,   128        ['block1-03_project_conv[0][0]']
#  malization)                    32)
#
#  block1-03_project_activation (  (None, None, None,   0          ['block1-03_project_bn[0][0]']
#  Activation)                    32)
#
#  block1-03_drop (Dropout)       (None, None, None,   0           ['block1-03_project_activation[0]
#                                 32)                              [0]']
#
#  block1-03_add (Add)            (None, None, None,   0           ['block1-03_drop[0][0]',
#                                 32)                               'block1-02_add[0][0]']
#
#  block1-04_project_conv (Conv2D  (None, None, None,   9216       ['block1-03_add[0][0]']
#  )                              32)
#
#  block1-04_project_bn (BatchNor  (None, None, None,   128        ['block1-04_project_conv[0][0]']
#  malization)                    32)
#
#  block1-04_project_activation (  (None, None, None,   0          ['block1-04_project_bn[0][0]']
#  Activation)                    32)
#
#  block1-04_drop (Dropout)       (None, None, None,   0           ['block1-04_project_activation[0]
#                                 32)                              [0]']
#
#  block1-04_add (Add)            (None, None, None,   0           ['block1-04_drop[0][0]',
#                                 32)                               'block1-03_add[0][0]']
#
#  block2-01_expand_conv (Conv2D)  (None, None, None,   36864      ['block1-04_add[0][0]']
#                                 128)
#
#  block2-01_expand_bn (BatchNorm  (None, None, None,   512        ['block2-01_expand_conv[0][0]']
#  alization)                     128)
#
#  block2-01_expand_activation (A  (None, None, None,   0          ['block2-01_expand_bn[0][0]']
#  ctivation)                     128)
#
#  block2-01_project_conv (Conv2D  (None, None, None,   8192       ['block2-01_expand_activation[0][
#  )                              64)                              0]']
#
#  block2-01_project_bn (BatchNor  (None, None, None,   256        ['block2-01_project_conv[0][0]']
#  malization)                    64)
#
#  block2-02_expand_conv (Conv2D)  (None, None, None,   147456     ['block2-01_project_bn[0][0]']
#                                 256)
#
#  block2-02_expand_bn (BatchNorm  (None, None, None,   1024       ['block2-02_expand_conv[0][0]']
#  alization)                     256)
#
#  block2-02_expand_activation (A  (None, None, None,   0          ['block2-02_expand_bn[0][0]']
#  ctivation)                     256)
#
#  block2-02_project_conv (Conv2D  (None, None, None,   16384      ['block2-02_expand_activation[0][
#  )                              64)                              0]']
#
#  block2-02_project_bn (BatchNor  (None, None, None,   256        ['block2-02_project_conv[0][0]']
#  malization)                    64)
#
#  block2-02_drop (Dropout)       (None, None, None,   0           ['block2-02_project_bn[0][0]']
#                                 64)
#
#  block2-02_add (Add)            (None, None, None,   0           ['block2-02_drop[0][0]',
#                                 64)                               'block2-01_project_bn[0][0]']
#
#  block2-03_expand_conv (Conv2D)  (None, None, None,   147456     ['block2-02_add[0][0]']
#                                 256)
#
#  block2-03_expand_bn (BatchNorm  (None, None, None,   1024       ['block2-03_expand_conv[0][0]']
#  alization)                     256)
#
#  block2-03_expand_activation (A  (None, None, None,   0          ['block2-03_expand_bn[0][0]']
#  ctivation)                     256)
#
#  block2-03_project_conv (Conv2D  (None, None, None,   16384      ['block2-03_expand_activation[0][
#  )                              64)                              0]']
#
#  block2-03_project_bn (BatchNor  (None, None, None,   256        ['block2-03_project_conv[0][0]']
#  malization)                    64)
#
#  block2-03_drop (Dropout)       (None, None, None,   0           ['block2-03_project_bn[0][0]']
#                                 64)
#
#  block2-03_add (Add)            (None, None, None,   0           ['block2-03_drop[0][0]',
#                                 64)                               'block2-02_add[0][0]']
#
#  block2-04_expand_conv (Conv2D)  (None, None, None,   147456     ['block2-03_add[0][0]']
#                                 256)
#
#  block2-04_expand_bn (BatchNorm  (None, None, None,   1024       ['block2-04_expand_conv[0][0]']
#  alization)                     256)
#
#  block2-04_expand_activation (A  (None, None, None,   0          ['block2-04_expand_bn[0][0]']
#  ctivation)                     256)
#
#  block2-04_project_conv (Conv2D  (None, None, None,   16384      ['block2-04_expand_activation[0][
#  )                              64)                              0]']
#
#  block2-04_project_bn (BatchNor  (None, None, None,   256        ['block2-04_project_conv[0][0]']
#  malization)                    64)
#
#  block2-04_drop (Dropout)       (None, None, None,   0           ['block2-04_project_bn[0][0]']
#                                 64)
#
#  block2-04_add (Add)            (None, None, None,   0           ['block2-04_drop[0][0]',
#                                 64)                               'block2-03_add[0][0]']
#
#  block2-05_expand_conv (Conv2D)  (None, None, None,   147456     ['block2-04_add[0][0]']
#                                 256)
#
#  block2-05_expand_bn (BatchNorm  (None, None, None,   1024       ['block2-05_expand_conv[0][0]']
#  alization)                     256)
#
#  block2-05_expand_activation (A  (None, None, None,   0          ['block2-05_expand_bn[0][0]']
#  ctivation)                     256)
#
#  block2-05_project_conv (Conv2D  (None, None, None,   16384      ['block2-05_expand_activation[0][
#  )                              64)                              0]']
#
#  block2-05_project_bn (BatchNor  (None, None, None,   256        ['block2-05_project_conv[0][0]']
#  malization)                    64)
#
#  block2-05_drop (Dropout)       (None, None, None,   0           ['block2-05_project_bn[0][0]']
#                                 64)
#
#  block2-05_add (Add)            (None, None, None,   0           ['block2-05_drop[0][0]',
#                                 64)                               'block2-04_add[0][0]']
#
#  block2-06_expand_conv (Conv2D)  (None, None, None,   147456     ['block2-05_add[0][0]']
#                                 256)
#
#  block2-06_expand_bn (BatchNorm  (None, None, None,   1024       ['block2-06_expand_conv[0][0]']
#  alization)                     256)
#
#  block2-06_expand_activation (A  (None, None, None,   0          ['block2-06_expand_bn[0][0]']
#  ctivation)                     256)
#
#  block2-06_project_conv (Conv2D  (None, None, None,   16384      ['block2-06_expand_activation[0][
#  )                              64)                              0]']
#
#  block2-06_project_bn (BatchNor  (None, None, None,   256        ['block2-06_project_conv[0][0]']
#  malization)                    64)
#
#  block2-06_drop (Dropout)       (None, None, None,   0           ['block2-06_project_bn[0][0]']
#                                 64)
#
#  block2-06_add (Add)            (None, None, None,   0           ['block2-06_drop[0][0]',
#                                 64)                               'block2-05_add[0][0]']
#
#  block2-07_expand_conv (Conv2D)  (None, None, None,   147456     ['block2-06_add[0][0]']
#                                 256)
#
#  block2-07_expand_bn (BatchNorm  (None, None, None,   1024       ['block2-07_expand_conv[0][0]']
#  alization)                     256)
#
#  block2-07_expand_activation (A  (None, None, None,   0          ['block2-07_expand_bn[0][0]']
#  ctivation)                     256)
#
#  block2-07_project_conv (Conv2D  (None, None, None,   16384      ['block2-07_expand_activation[0][
#  )                              64)                              0]']
#
#  block2-07_project_bn (BatchNor  (None, None, None,   256        ['block2-07_project_conv[0][0]']
#  malization)                    64)
#
#  block2-07_drop (Dropout)       (None, None, None,   0           ['block2-07_project_bn[0][0]']
#                                 64)
#
#  block2-07_add (Add)            (None, None, None,   0           ['block2-07_drop[0][0]',
#                                 64)                               'block2-06_add[0][0]']
#
#  block3-01_expand_conv (Conv2D)  (None, None, None,   147456     ['block2-07_add[0][0]']
#                                 256)
#
#  block3-01_expand_bn (BatchNorm  (None, None, None,   1024       ['block3-01_expand_conv[0][0]']
#  alization)                     256)
#
#  block3-01_expand_activation (A  (None, None, None,   0          ['block3-01_expand_bn[0][0]']
#  ctivation)                     256)
#
#  block3-01_project_conv (Conv2D  (None, None, None,   24576      ['block3-01_expand_activation[0][
#  )                              96)                              0]']
#
#  block3-01_project_bn (BatchNor  (None, None, None,   384        ['block3-01_project_conv[0][0]']
#  malization)                    96)
#
#  block3-02_expand_conv (Conv2D)  (None, None, None,   331776     ['block3-01_project_bn[0][0]']
#                                 384)
#
#  block3-02_expand_bn (BatchNorm  (None, None, None,   1536       ['block3-02_expand_conv[0][0]']
#  alization)                     384)
#
#  block3-02_expand_activation (A  (None, None, None,   0          ['block3-02_expand_bn[0][0]']
#  ctivation)                     384)
#
#  block3-02_project_conv (Conv2D  (None, None, None,   36864      ['block3-02_expand_activation[0][
#  )                              96)                              0]']
#
#  block3-02_project_bn (BatchNor  (None, None, None,   384        ['block3-02_project_conv[0][0]']
#  malization)                    96)
#
#  block3-02_drop (Dropout)       (None, None, None,   0           ['block3-02_project_bn[0][0]']
#                                 96)
#
#  block3-02_add (Add)            (None, None, None,   0           ['block3-02_drop[0][0]',
#                                 96)                               'block3-01_project_bn[0][0]']
#
#  block3-03_expand_conv (Conv2D)  (None, None, None,   331776     ['block3-02_add[0][0]']
#                                 384)
#
#  block3-03_expand_bn (BatchNorm  (None, None, None,   1536       ['block3-03_expand_conv[0][0]']
#  alization)                     384)
#
#  block3-03_expand_activation (A  (None, None, None,   0          ['block3-03_expand_bn[0][0]']
#  ctivation)                     384)
#
#  block3-03_project_conv (Conv2D  (None, None, None,   36864      ['block3-03_expand_activation[0][
#  )                              96)                              0]']
#
#  block3-03_project_bn (BatchNor  (None, None, None,   384        ['block3-03_project_conv[0][0]']
#  malization)                    96)
#
#  block3-03_drop (Dropout)       (None, None, None,   0           ['block3-03_project_bn[0][0]']
#                                 96)
#
#  block3-03_add (Add)            (None, None, None,   0           ['block3-03_drop[0][0]',
#                                 96)                               'block3-02_add[0][0]']
#
#  block3-04_expand_conv (Conv2D)  (None, None, None,   331776     ['block3-03_add[0][0]']
#                                 384)
#
#  block3-04_expand_bn (BatchNorm  (None, None, None,   1536       ['block3-04_expand_conv[0][0]']
#  alization)                     384)
#
#  block3-04_expand_activation (A  (None, None, None,   0          ['block3-04_expand_bn[0][0]']
#  ctivation)                     384)
#
#  block3-04_project_conv (Conv2D  (None, None, None,   36864      ['block3-04_expand_activation[0][
#  )                              96)                              0]']
#
#  block3-04_project_bn (BatchNor  (None, None, None,   384        ['block3-04_project_conv[0][0]']
#  malization)                    96)
#
#  block3-04_drop (Dropout)       (None, None, None,   0           ['block3-04_project_bn[0][0]']
#                                 96)
#
#  block3-04_add (Add)            (None, None, None,   0           ['block3-04_drop[0][0]',
#                                 96)                               'block3-03_add[0][0]']
#
#  block3-05_expand_conv (Conv2D)  (None, None, None,   331776     ['block3-04_add[0][0]']
#                                 384)
#
#  block3-05_expand_bn (BatchNorm  (None, None, None,   1536       ['block3-05_expand_conv[0][0]']
#  alization)                     384)
#
#  block3-05_expand_activation (A  (None, None, None,   0          ['block3-05_expand_bn[0][0]']
#  ctivation)                     384)
#
#  block3-05_project_conv (Conv2D  (None, None, None,   36864      ['block3-05_expand_activation[0][
#  )                              96)                              0]']
#
#  block3-05_project_bn (BatchNor  (None, None, None,   384        ['block3-05_project_conv[0][0]']
#  malization)                    96)
#
#  block3-05_drop (Dropout)       (None, None, None,   0           ['block3-05_project_bn[0][0]']
#                                 96)
#
#  block3-05_add (Add)            (None, None, None,   0           ['block3-05_drop[0][0]',
#                                 96)                               'block3-04_add[0][0]']
#
#  block3-06_expand_conv (Conv2D)  (None, None, None,   331776     ['block3-05_add[0][0]']
#                                 384)
#
#  block3-06_expand_bn (BatchNorm  (None, None, None,   1536       ['block3-06_expand_conv[0][0]']
#  alization)                     384)
#
#  block3-06_expand_activation (A  (None, None, None,   0          ['block3-06_expand_bn[0][0]']
#  ctivation)                     384)
#
#  block3-06_project_conv (Conv2D  (None, None, None,   36864      ['block3-06_expand_activation[0][
#  )                              96)                              0]']
#
#  block3-06_project_bn (BatchNor  (None, None, None,   384        ['block3-06_project_conv[0][0]']
#  malization)                    96)
#
#  block3-06_drop (Dropout)       (None, None, None,   0           ['block3-06_project_bn[0][0]']
#                                 96)
#
#  block3-06_add (Add)            (None, None, None,   0           ['block3-06_drop[0][0]',
#                                 96)                               'block3-05_add[0][0]']
#
#  block3-07_expand_conv (Conv2D)  (None, None, None,   331776     ['block3-06_add[0][0]']
#                                 384)
#
#  block3-07_expand_bn (BatchNorm  (None, None, None,   1536       ['block3-07_expand_conv[0][0]']
#  alization)                     384)
#
#  block3-07_expand_activation (A  (None, None, None,   0          ['block3-07_expand_bn[0][0]']
#  ctivation)                     384)
#
#  block3-07_project_conv (Conv2D  (None, None, None,   36864      ['block3-07_expand_activation[0][
#  )                              96)                              0]']
#
#  block3-07_project_bn (BatchNor  (None, None, None,   384        ['block3-07_project_conv[0][0]']
#  malization)                    96)
#
#  block3-07_drop (Dropout)       (None, None, None,   0           ['block3-07_project_bn[0][0]']
#                                 96)
#
#  block3-07_add (Add)            (None, None, None,   0           ['block3-07_drop[0][0]',
#                                 96)                               'block3-06_add[0][0]']
#
#  block4-01_expand_conv (Conv2D)  (None, None, None,   36864      ['block3-07_add[0][0]']
#                                 384)
#
#  block4-01_expand_bn (BatchNorm  (None, None, None,   1536       ['block4-01_expand_conv[0][0]']
#  alization)                     384)
#
#  block4-01_expand_activation (A  (None, None, None,   0          ['block4-01_expand_bn[0][0]']
#  ctivation)                     384)
#
#  block4-01_dwconv2 (DepthwiseCo  (None, None, None,   3456       ['block4-01_expand_activation[0][
#  nv2D)                          384)                             0]']
#
#  block4-01_bn (BatchNormalizati  (None, None, None,   1536       ['block4-01_dwconv2[0][0]']
#  on)                            384)
#
#  block4-01_activation (Activati  (None, None, None,   0          ['block4-01_bn[0][0]']
#  on)                            384)
#
#  block4-01_se_squeeze (GlobalAv  (None, 384)         0           ['block4-01_activation[0][0]']
#  eragePooling2D)
#
#  block4-01_se_reshape (Reshape)  (None, 1, 1, 384)   0           ['block4-01_se_squeeze[0][0]']
#
#  block4-01_se_reduce (Conv2D)   (None, 1, 1, 24)     9240        ['block4-01_se_reshape[0][0]']
#
#  block4-01_se_expand (Conv2D)   (None, 1, 1, 384)    9600        ['block4-01_se_reduce[0][0]']
#
#  block4-01_se_excite (Multiply)  (None, None, None,   0          ['block4-01_activation[0][0]',
#                                 384)                              'block4-01_se_expand[0][0]']
#
#  block4-01_project_conv (Conv2D  (None, None, None,   73728      ['block4-01_se_excite[0][0]']
#  )                              192)
#
#  block4-01_project_bn (BatchNor  (None, None, None,   768        ['block4-01_project_conv[0][0]']
#  malization)                    192)
#
#  block4-02_expand_conv (Conv2D)  (None, None, None,   147456     ['block4-01_project_bn[0][0]']
#                                 768)
#
#  block4-02_expand_bn (BatchNorm  (None, None, None,   3072       ['block4-02_expand_conv[0][0]']
#  alization)                     768)
#
#  block4-02_expand_activation (A  (None, None, None,   0          ['block4-02_expand_bn[0][0]']
#  ctivation)                     768)
#
#  block4-02_dwconv2 (DepthwiseCo  (None, None, None,   6912       ['block4-02_expand_activation[0][
#  nv2D)                          768)                             0]']
#
#  block4-02_bn (BatchNormalizati  (None, None, None,   3072       ['block4-02_dwconv2[0][0]']
#  on)                            768)
#
#  block4-02_activation (Activati  (None, None, None,   0          ['block4-02_bn[0][0]']
#  on)                            768)
#
#  block4-02_se_squeeze (GlobalAv  (None, 768)         0           ['block4-02_activation[0][0]']
#  eragePooling2D)
#
#  block4-02_se_reshape (Reshape)  (None, 1, 1, 768)   0           ['block4-02_se_squeeze[0][0]']
#
#  block4-02_se_reduce (Conv2D)   (None, 1, 1, 48)     36912       ['block4-02_se_reshape[0][0]']
#
#  block4-02_se_expand (Conv2D)   (None, 1, 1, 768)    37632       ['block4-02_se_reduce[0][0]']
#
#  block4-02_se_excite (Multiply)  (None, None, None,   0          ['block4-02_activation[0][0]',
#                                 768)                              'block4-02_se_expand[0][0]']
#
#  block4-02_project_conv (Conv2D  (None, None, None,   147456     ['block4-02_se_excite[0][0]']
#  )                              192)
#
#  block4-02_project_bn (BatchNor  (None, None, None,   768        ['block4-02_project_conv[0][0]']
#  malization)                    192)
#
#  block4-02_drop (Dropout)       (None, None, None,   0           ['block4-02_project_bn[0][0]']
#                                 192)
#
#  block4-02_add (Add)            (None, None, None,   0           ['block4-02_drop[0][0]',
#                                 192)                              'block4-01_project_bn[0][0]']
#
#  block4-03_expand_conv (Conv2D)  (None, None, None,   147456     ['block4-02_add[0][0]']
#                                 768)
#
#  block4-03_expand_bn (BatchNorm  (None, None, None,   3072       ['block4-03_expand_conv[0][0]']
#  alization)                     768)
#
#  block4-03_expand_activation (A  (None, None, None,   0          ['block4-03_expand_bn[0][0]']
#  ctivation)                     768)
#
#  block4-03_dwconv2 (DepthwiseCo  (None, None, None,   6912       ['block4-03_expand_activation[0][
#  nv2D)                          768)                             0]']
#
#  block4-03_bn (BatchNormalizati  (None, None, None,   3072       ['block4-03_dwconv2[0][0]']
#  on)                            768)
#
#  block4-03_activation (Activati  (None, None, None,   0          ['block4-03_bn[0][0]']
#  on)                            768)
#
#  block4-03_se_squeeze (GlobalAv  (None, 768)         0           ['block4-03_activation[0][0]']
#  eragePooling2D)
#
#  block4-03_se_reshape (Reshape)  (None, 1, 1, 768)   0           ['block4-03_se_squeeze[0][0]']
#
#  block4-03_se_reduce (Conv2D)   (None, 1, 1, 48)     36912       ['block4-03_se_reshape[0][0]']
#
#  block4-03_se_expand (Conv2D)   (None, 1, 1, 768)    37632       ['block4-03_se_reduce[0][0]']
#
#  block4-03_se_excite (Multiply)  (None, None, None,   0          ['block4-03_activation[0][0]',
#                                 768)                              'block4-03_se_expand[0][0]']
#
#  block4-03_project_conv (Conv2D  (None, None, None,   147456     ['block4-03_se_excite[0][0]']
#  )                              192)
#
#  block4-03_project_bn (BatchNor  (None, None, None,   768        ['block4-03_project_conv[0][0]']
#  malization)                    192)
#
#  block4-03_drop (Dropout)       (None, None, None,   0           ['block4-03_project_bn[0][0]']
#                                 192)
#
#  block4-03_add (Add)            (None, None, None,   0           ['block4-03_drop[0][0]',
#                                 192)                              'block4-02_add[0][0]']
#
#  block4-04_expand_conv (Conv2D)  (None, None, None,   147456     ['block4-03_add[0][0]']
#                                 768)
#
#  block4-04_expand_bn (BatchNorm  (None, None, None,   3072       ['block4-04_expand_conv[0][0]']
#  alization)                     768)
#
#  block4-04_expand_activation (A  (None, None, None,   0          ['block4-04_expand_bn[0][0]']
#  ctivation)                     768)
#
# ...
#
#  block7-04_project_bn (BatchNor  (None, None, None,   2560       ['block7-04_project_conv[0][0]']
#  malization)                    640)
#
#  block7-04_drop (Dropout)       (None, None, None,   0           ['block7-04_project_bn[0][0]']
#                                 640)
#
#  block7-04_add (Add)            (None, None, None,   0           ['block7-04_drop[0][0]',
#                                 640)                              'block7-03_add[0][0]']
#
#  block7-05_expand_conv (Conv2D)  (None, None, None,   2457600    ['block7-04_add[0][0]']
#                                 3840)
#
#  block7-05_expand_bn (BatchNorm  (None, None, None,   15360      ['block7-05_expand_conv[0][0]']
#  alization)                     3840)
#
#  block7-05_expand_activation (A  (None, None, None,   0          ['block7-05_expand_bn[0][0]']
#  ctivation)                     3840)
#
#  block7-05_dwconv2 (DepthwiseCo  (None, None, None,   34560      ['block7-05_expand_activation[0][
#  nv2D)                          3840)                            0]']
#
#  block7-05_bn (BatchNormalizati  (None, None, None,   15360      ['block7-05_dwconv2[0][0]']
#  on)                            3840)
#
#  block7-05_activation (Activati  (None, None, None,   0          ['block7-05_bn[0][0]']
#  on)                            3840)
#
#  block7-05_se_squeeze (GlobalAv  (None, 3840)        0           ['block7-05_activation[0][0]']
#  eragePooling2D)
#
#  block7-05_se_reshape (Reshape)  (None, 1, 1, 3840)  0           ['block7-05_se_squeeze[0][0]']
#
#  block7-05_se_reduce (Conv2D)   (None, 1, 1, 160)    614560      ['block7-05_se_reshape[0][0]']
#
#  block7-05_se_expand (Conv2D)   (None, 1, 1, 3840)   618240      ['block7-05_se_reduce[0][0]']
#
#  block7-05_se_excite (Multiply)  (None, None, None,   0          ['block7-05_activation[0][0]',
#                                 3840)                             'block7-05_se_expand[0][0]']
#
#  block7-05_project_conv (Conv2D  (None, None, None,   2457600    ['block7-05_se_excite[0][0]']
#  )                              640)
#
#  block7-05_project_bn (BatchNor  (None, None, None,   2560       ['block7-05_project_conv[0][0]']
#  malization)                    640)
#
#  block7-05_drop (Dropout)       (None, None, None,   0           ['block7-05_project_bn[0][0]']
#                                 640)
#
#  block7-05_add (Add)            (None, None, None,   0           ['block7-05_drop[0][0]',
#                                 640)                              'block7-04_add[0][0]']
#
#  block7-06_expand_conv (Conv2D)  (None, None, None,   2457600    ['block7-05_add[0][0]']
#                                 3840)
#
#  block7-06_expand_bn (BatchNorm  (None, None, None,   15360      ['block7-06_expand_conv[0][0]']
#  alization)                     3840)
#
#  block7-06_expand_activation (A  (None, None, None,   0          ['block7-06_expand_bn[0][0]']
#  ctivation)                     3840)
#
#  block7-06_dwconv2 (DepthwiseCo  (None, None, None,   34560      ['block7-06_expand_activation[0][
#  nv2D)                          3840)                            0]']
#
#  block7-06_bn (BatchNormalizati  (None, None, None,   15360      ['block7-06_dwconv2[0][0]']
#  on)                            3840)
#
#  block7-06_activation (Activati  (None, None, None,   0          ['block7-06_bn[0][0]']
#  on)                            3840)
#
#  block7-06_se_squeeze (GlobalAv  (None, 3840)        0           ['block7-06_activation[0][0]']
#  eragePooling2D)
#
#  block7-06_se_reshape (Reshape)  (None, 1, 1, 3840)  0           ['block7-06_se_squeeze[0][0]']
#
#  block7-06_se_reduce (Conv2D)   (None, 1, 1, 160)    614560      ['block7-06_se_reshape[0][0]']
#
#  block7-06_se_expand (Conv2D)   (None, 1, 1, 3840)   618240      ['block7-06_se_reduce[0][0]']
#
#  block7-06_se_excite (Multiply)  (None, None, None,   0          ['block7-06_activation[0][0]',
#                                 3840)                             'block7-06_se_expand[0][0]']
#
#  block7-06_project_conv (Conv2D  (None, None, None,   2457600    ['block7-06_se_excite[0][0]']
#  )                              640)
#
#  block7-06_project_bn (BatchNor  (None, None, None,   2560       ['block7-06_project_conv[0][0]']
#  malization)                    640)
#
#  block7-06_drop (Dropout)       (None, None, None,   0           ['block7-06_project_bn[0][0]']
#                                 640)
#
#  block7-06_add (Add)            (None, None, None,   0           ['block7-06_drop[0][0]',
#                                 640)                              'block7-05_add[0][0]']
#
#  block7-07_expand_conv (Conv2D)  (None, None, None,   2457600    ['block7-06_add[0][0]']
#                                 3840)
#
#  block7-07_expand_bn (BatchNorm  (None, None, None,   15360      ['block7-07_expand_conv[0][0]']
#  alization)                     3840)
#
#  block7-07_expand_activation (A  (None, None, None,   0          ['block7-07_expand_bn[0][0]']
#  ctivation)                     3840)
#
#  block7-07_dwconv2 (DepthwiseCo  (None, None, None,   34560      ['block7-07_expand_activation[0][
#  nv2D)                          3840)                            0]']
#
#  block7-07_bn (BatchNormalizati  (None, None, None,   15360      ['block7-07_dwconv2[0][0]']
#  on)                            3840)
#
#  block7-07_activation (Activati  (None, None, None,   0          ['block7-07_bn[0][0]']
#  on)                            3840)
#
#  block7-07_se_squeeze (GlobalAv  (None, 3840)        0           ['block7-07_activation[0][0]']
#  eragePooling2D)
#
#  block7-07_se_reshape (Reshape)  (None, 1, 1, 3840)  0           ['block7-07_se_squeeze[0][0]']
#
#  block7-07_se_reduce (Conv2D)   (None, 1, 1, 160)    614560      ['block7-07_se_reshape[0][0]']
#
#  block7-07_se_expand (Conv2D)   (None, 1, 1, 3840)   618240      ['block7-07_se_reduce[0][0]']
#
#  block7-07_se_excite (Multiply)  (None, None, None,   0          ['block7-07_activation[0][0]',
#                                 3840)                             'block7-07_se_expand[0][0]']
#
#  block7-07_project_conv (Conv2D  (None, None, None,   2457600    ['block7-07_se_excite[0][0]']
#  )                              640)
#
#  block7-07_project_bn (BatchNor  (None, None, None,   2560       ['block7-07_project_conv[0][0]']
#  malization)                    640)
#
#  block7-07_drop (Dropout)       (None, None, None,   0           ['block7-07_project_bn[0][0]']
#                                 640)
#
#  block7-07_add (Add)            (None, None, None,   0           ['block7-07_drop[0][0]',
#                                 640)                              'block7-06_add[0][0]']
#
#  top_conv (Conv2D)              (None, None, None,   819200      ['block7-07_add[0][0]']
#                                 1280)
#
#  top_bn (BatchNormalization)    (None, None, None,   5120        ['top_conv[0][0]']
#                                 1280)
#
#  top_activation (Activation)    (None, None, None,   0           ['top_bn[0][0]']
#                                 1280)
#
#  global_avg_pool (GlobalAverage  (None, 1280)        0           ['top_activation[0][0]']
#  Pooling2D)
#
#  dense_1 (Dense)                (None, 1024)         1311744     ['global_avg_pool[0][0]']
#
#  dropout_1 (Dropout)            (None, 1024)         0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 256)          262400      ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 256)          0           ['dense_2[0][0]']
#
#  dense_pred (Dense)             (None, 5)            1285        ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 119,322,277
# Trainable params: 118,809,701
# Non-trainable params: 512,576
# __________________________________________________________________________________________________

# %%
# ja foi comentado nos arquivos auxiliares
early_stop_epocas = 10
check_epocas = 10
reduce_lr_epocas = 2
fator_reduce_lr = 0.7 # fator de reducao, vai multiplicar a lr por ele, se eu coloco 0.3, vai diminuir a lr em 70%

check_best = True
check = True
early_stop = True
log = True
reduce_lr = True

callbacks_treino = callbacks(
    dir_modelos_salvos = dir_modelos_salvos, 
    dir_csv_log = dir_csv_log_treino,
    check_best = check_best, 
    check = check, 
    early_stop = early_stop, 
    log = log, 
    reduce_lr = reduce_lr,
    early_stop_epocas = early_stop_epocas,
    check_epocas = check_epocas,
    reduce_lr_epocas = reduce_lr_epocas,
    fator_reduce_lr = fator_reduce_lr
    )
# Out:
# callbacks adicionados:
# check best
# check 10
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# early stop
# log
# reduzindo lr

# %% [markdown]
# ##
# <font size=5 color='white'> 4 - Treinar modelo

# %%
# ja foi comentado nos arquivos auxiliares
steps_per_epoch = len(dados_treino) // batch_size
validation_steps=len(dados_validacao) // batch_size

start_time = time.time()

model.fit(
    dataset_treino, 
    validation_data = dataset_validacao, 
    steps_per_epoch = steps_per_epoch, 
    validation_steps = validation_steps, 
    epochs = epocas,
    callbacks=callbacks_treino
    )

end_time = time.time()

tempo_treino = end_time - start_time
print(tempo_treino)
# Out:
# Epoch 1/100
# 339/339 [==============================] - ETA: 0s - loss: 1.5002 - categorical_accuracy: 0.3788 - precision: 0.6452 - recall: 0.0354 - auc: 0.6658
# Epoch 1: val_loss improved from inf to 1.39554, saving model to ./redes/EfficientNetV2L/modelos_salvos\EfficientNetV2L-10_epoca_01.hdf5
# 339/339 [==============================] - 113s 255ms/step - loss: 1.5002 - categorical_accuracy: 0.3788 - precision: 0.6452 - recall: 0.0354 - auc: 0.6658 - val_loss: 1.3955 - val_categorical_accuracy: 0.4500 - val_precision: 0.7419 - val_recall: 0.0767 - val_auc: 0.7625 - lr: 1.0000e-05
# Epoch 2/100
# 339/339 [==============================] - ETA: 0s - loss: 1.3402 - categorical_accuracy: 0.4696 - precision: 0.6648 - recall: 0.1418 - auc: 0.7729
# Epoch 2: val_loss improved from 1.39554 to 1.26714, saving model to ./redes/EfficientNetV2L/modelos_salvos\EfficientNetV2L-10_epoca_02.hdf5
# 339/339 [==============================] - 90s 264ms/step - loss: 1.3402 - categorical_accuracy: 0.4696 - precision: 0.6648 - recall: 0.1418 - auc: 0.7729 - val_loss: 1.2671 - val_categorical_accuracy: 0.5367 - val_precision: 0.8529 - val_recall: 0.0967 - val_auc: 0.8318 - lr: 1.0000e-05
# Epoch 3/100
# 339/339 [==============================] - ETA: 0s - loss: 1.1551 - categorical_accuracy: 0.5310 - precision: 0.7150 - recall: 0.2682 - auc: 0.8361
# Epoch 3: val_loss improved from 1.26714 to 1.11819, saving model to ./redes/EfficientNetV2L/modelos_salvos\EfficientNetV2L-10_epoca_03.hdf5
# 339/339 [==============================] - 89s 262ms/step - loss: 1.1551 - categorical_accuracy: 0.5310 - precision: 0.7150 - recall: 0.2682 - auc: 0.8361 - val_loss: 1.1182 - val_categorical_accuracy: 0.5867 - val_precision: 0.8400 - val_recall: 0.2100 - val_auc: 0.8696 - lr: 1.0000e-05
# Epoch 4/100
# 339/339 [==============================] - ETA: 0s - loss: 1.0561 - categorical_accuracy: 0.5907 - precision: 0.7167 - recall: 0.3556 - auc: 0.8611
# Epoch 4: val_loss improved from 1.11819 to 1.08200, saving model to ./redes/EfficientNetV2L/modelos_salvos\EfficientNetV2L-10_epoca_04.hdf5
# 339/339 [==============================] - 101s 298ms/step - loss: 1.0561 - categorical_accuracy: 0.5907 - precision: 0.7167 - recall: 0.3556 - auc: 0.8611 - val_loss: 1.0820 - val_categorical_accuracy: 0.5567 - val_precision: 0.7158 - val_recall: 0.2267 - val_auc: 0.8628 - lr: 1.0000e-05
# Epoch 5/100
#   9/339 [..............................] - ETA: 3:54 - loss: 0.9867 - categorical_accuracy: 0.6512 - precision: 0.6667 - recall: 0.3721 - auc: 0.8805

# %% [markdown]
# ##
# <font size=5 color='white'> 5 - Avaliar modelo

# %%
# ja foi comentado nos arquivos auxiliares
avaliar_modelo(
    model=model,
    rede=rede,
    id_rodada=id_rodada,  
    dataset_teste=dataset_teste,
    dados_teste=dados_teste,
    batch_size=batch_size,
    imagenet=imagenet,
    data_aug=data_aug,
    nome_otimizador=nome_otimizador,
    nome_loss=nome_loss,
    lr=lr,
    attention=attention,
    camada_pooling=camada_pooling,
    flatten=flatten,
    denses=denses,
    dropouts=dropouts,
    tempo_treino=tempo_treino
)

# %%
dir_previsoes = './log_teste/previsoes'
for nome_arquivo in os.listdir(dir_previsoes):
    if nome_arquivo.startswith(f'resultados_{rede}-{id_rodada}'):
        nome_modelo = '_'.join(nome_arquivo.split('_')[1:]).replace('.csv', '')
        matriz_confusao(nome_modelo)
